# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import ipywidgets as widgets
from functools import partial
from wrwc.config import RAW_DATA_DIR, PROCESSED_DATA_DIR
# Out:
# 2025-07-03 10:45:06.860 | INFO     | wrwc.config:<module>:11 - PROJ_ROOT path is: /Users/gdang2/repos/wrwc-water-quality

# %% [markdown]
# ## I. Data Processing and Shape

# %%
df_data_raw = pd.read_csv(RAW_DATA_DIR / 'WoonasquatucketData.csv')
df_data = df_data_raw.copy()

# Standardize column names
df_data.columns = [col.replace(" ", "_").lower() for col in df_data.columns]

# Create dictionary of parameter codes to parameter name
param_code_to_name = {s.split('-')[-1].strip(): s.split('-')[0].strip() for s in df_data.parameter.unique()}
shortened_names = {'00915': 'Calcium',
                   '32209': 'Chlorophyll a',
                   '82903': 'Depth',
                   '00631': 'Nitrate + Nitrite',
                   '00930': 'Sodium',
                   '00600': 'Nitrogen, Total',
                   '00608': 'Nitrogen, Ammonia',
                  }
param_code_to_name.update(shortened_names)

# Read Site info 
df_site = pd.read_csv(RAW_DATA_DIR / 'SiteInfo.csv')
df_site.columns = [col.replace(" ", "_").lower() for col in df_site.columns]
df_site.rename(columns={'ww_station': 'ww_id'}, inplace=True)


# Process dataframe
df_data = (
    df_data
    # Create datetime, parameter code, and parameter name columns
    .assign(date=pd.to_datetime(df_data['date_of_sample']),
            param_code=[s.split('-')[-1].strip() for s in df_data['parameter']])
    .assign(parameter=lambda x: [param_code_to_name[s] for s in x['param_code']])
    # Drop no data or redundant columns
    .dropna(subset='concentration')
    .drop(columns=['sediment_particle_size', 'particle_size_unit', 'fish_sample_type', 'fish_taxa', 'date_of_sample'])
    .merge(df_site.loc[:, ['ww_id', 'wbid', 'wb_type', 'site_descr', 'lat_dd', 'lon_dd']], on='ww_id', how='left')
    .set_index('date')
)


df_data.head()
# Out:
#                      source.name  ww_id         time sample_type sample_media  \
# date
# 1990-04-28  URIWW-1990-Lakes.csv  WW016  12:00:00 PM   Composite        Water
# 1990-05-05  URIWW-1990-Lakes.csv  WW016  10:30:00 AM        Grab        Water
# 1990-05-05  URIWW-1990-Lakes.csv  WW016  10:30:00 AM        Grab        Water
# 1990-05-05  URIWW-1990-Lakes.csv  WW016  10:30:00 AM        Grab        Water
# 1990-05-05  URIWW-1990-Lakes.csv  WW016  10:30:00 AM        Grab        Water
#
#             depth      parameter  concentration  unit qualifier_code  ...  \
# date                                                                  ...
# 1990-04-28    NaN   Secchi Depth          2.025     m            NaN  ...
# 1990-05-05    1.0     Alkalinity          8.700  mg/l            NaN  ...
# 1990-05-05    1.0        Calcium          5.930  mg/l            NaN  ...
# 1990-05-05    1.0       Chloride         36.000  mg/l            NaN  ...
# 1990-05-05    1.0  Chlorophyll a          4.200  ug/l            NaN  ...
#
#             comments   monitoring_location              watershed  \
# date
# 1990-04-28       NaN  Geo @ Widow Sweet Rd  Woonasquatucket River
# 1990-05-05       NaN  Geo @ Widow Sweet Rd  Woonasquatucket River
# 1990-05-05       NaN  Geo @ Widow Sweet Rd  Woonasquatucket River
# 1990-05-05       NaN  Geo @ Widow Sweet Rd  Woonasquatucket River
# 1990-05-05    Analog  Geo @ Widow Sweet Rd  Woonasquatucket River
#
#            watershed_code param_code           wbid     wb_type  \
# date
# 1990-04-28             WO      00069  RI0002007L-02  Reservoir
# 1990-05-05             WO      00410  RI0002007L-02  Reservoir
# 1990-05-05             WO      00915  RI0002007L-02  Reservoir
# 1990-05-05             WO      00940  RI0002007L-02  Reservoir
# 1990-05-05             WO      32209  RI0002007L-02  Reservoir
#
#                    site_descr     lat_dd     lon_dd
# date
# 1990-04-28  Georgiaville Pond  41.892783 -71.511331
# 1990-05-05  Georgiaville Pond  41.892783 -71.511331
# 1990-05-05  Georgiaville Pond  41.892783 -71.511331
# 1990-05-05  Georgiaville Pond  41.892783 -71.511331
# 1990-05-05  Georgiaville Pond  41.892783 -71.511331
#
# [5 rows x 26 columns]

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 25620 entries, 1990-04-28 to 2021-10-23
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   source.name               25620 non-null  object
#  1   ww_id                     25620 non-null  object
#  2   time                      10720 non-null  object
#  3   sample_type               25620 non-null  object
#  4   sample_media              25620 non-null  object
#  5   depth                     20916 non-null  float64
#  6   parameter                 25620 non-null  object
#  7   concentration             25620 non-null  float64
#  8   unit                      25620 non-null  object
#  9   qualifier_code            1155 non-null   object
#  10  detection_limit           25619 non-null  float64
#  11  detection_limit_unit      25620 non-null  object
#  12  quantitation_level        24613 non-null  float64
#  13  quantitation_level_unit   25620 non-null  object
#  14  lab_name                  21243 non-null  object
#  15  analytical_method_number  17742 non-null  object
#  16  comments                  2330 non-null   object
#  17  monitoring_location       25620 non-null  object
#  18  watershed                 25620 non-null  object
#  19  watershed_code            25620 non-null  object
#  20  param_code                25620 non-null  object
#  21  wbid                      25183 non-null  object
#  22  wb_type                   25620 non-null  object
#  23  site_descr                25620 non-null  object
#  24  lat_dd                    25620 non-null  float64
#  25  lon_dd                    25620 non-null  float64
# dtypes: float64(6), object(20)
# memory usage: 5.3+ MB

# %% [markdown]
# ---
# ## II. Sample Counts
# Constructing table and heatmaps of sample counts by parameter and site.

# %%
# Heatmap function 
def heatmap(df, title):
    fig = go.Figure(data=go.Heatmap(
        z=df.values,
        x=df.columns,
        y=df.index,
        ))

    fig.update_layout(
        title=dict(text=title),
        xaxis_nticks=32)
    fig.update_xaxes(tickangle=90)
    
    fig.show()

# Calculate monthly counts by site and parameter 
df_counts = (
    df_data
    .groupby(['parameter', 'wb_type', 'ww_id'])
    .resample("MS")
    .size()
    .unstack(fill_value=0)
)
df_counts
# Out:
# date                              1990-04-01  1990-05-01  1990-06-01  \
# parameter  wb_type         ww_id
# Alkalinity Lake or Pond    WW201           0           0           0
#            Reservoir       WW016           0           1           0
#                            WW024           0           0           0
#                            WW046           0           0           0
#                            WW052           0           1           0
# ...                                      ...         ...         ...
# pH         Stream or river WW240           0           0           0
#                            WW241           0           0           0
#                            WW635           0           0           0
#                            WW679           0           0           0
#                            WW680           0           0           0
#
# date                              1990-07-01  1990-08-01  1990-09-01  \
# parameter  wb_type         ww_id
# Alkalinity Lake or Pond    WW201           0           0           0
#            Reservoir       WW016           1           0           0
#                            WW024           0           0           0
#                            WW046           1           0           0
#                            WW052           1           0           0
# ...                                      ...         ...         ...
# pH         Stream or river WW240           0           0           0
#                            WW241           0           0           0
#                            WW635           0           0           0
#                            WW679           0           0           0
#                            WW680           0           0           0
#
# date                              1990-10-01  1990-11-01  1990-12-01  \
# parameter  wb_type         ww_id
# Alkalinity Lake or Pond    WW201           0           0           0
#            Reservoir       WW016           0           1           0
#                            WW024           0           0           0
#                            WW046           0           1           0
#                            WW052           0           0           0
# ...                                      ...         ...         ...
# pH         Stream or river WW240           0           0           0
#                            WW241           0           0           0
#                            WW635           0           0           0
#                            WW679           0           0           0
#                            WW680           0           0           0
#
# date                              1991-01-01  ...  2021-01-01  2021-02-01  \
# parameter  wb_type         ww_id              ...
# Alkalinity Lake or Pond    WW201           0  ...           0           0
#            Reservoir       WW016           0  ...           0           0
#                            WW024           0  ...           0           0
#                            WW046           0  ...           0           0
#                            WW052           0  ...           0           0
# ...                                      ...  ...         ...         ...
# pH         Stream or river WW240           0  ...           0           0
#                            WW241           0  ...           0           0
#                            WW635           0  ...           0           0
#                            WW679           0  ...           0           0
#                            WW680           0  ...           0           0
#
# date                              2021-03-01  2021-04-01  2021-05-01  \
# parameter  wb_type         ww_id
# Alkalinity Lake or Pond    WW201           0           0           1
#            Reservoir       WW016           0           0           1
#                            WW024           0           0           0
#                            WW046           0           0           0
#                            WW052           0           0           0
# ...                                      ...         ...         ...
# pH         Stream or river WW240           0           0           0
#                            WW241           0           0           0
#                            WW635           0           0           1
#                            WW679           0           0           0
#                            WW680           0           0           1
#
# date                              2021-06-01  2021-07-01  2021-08-01  \
# parameter  wb_type         ww_id
# Alkalinity Lake or Pond    WW201           0           1           0
#            Reservoir       WW016           0           1           0
#                            WW024           0           0           0
#                            WW046           1           1           1
#                            WW052           0           0           0
# ...                                      ...         ...         ...
# pH         Stream or river WW240           0           0           0
#                            WW241           0           0           0
#                            WW635           1           1           1
#                            WW679           0           0           0
#                            WW680           0           1           0
#
# date                              2021-09-01  2021-10-01
# parameter  wb_type         ww_id
# Alkalinity Lake or Pond    WW201           0           1
#            Reservoir       WW016           1           1
#                            WW024           0           0
#                            WW046           1           1
#                            WW052           0           0
# ...                                      ...         ...
# pH         Stream or river WW240           0           0
#                            WW241           0           0
#                            WW635           2           1
#                            WW679           0           0
#                            WW680           2           1
#
# [345 rows x 379 columns]

# %% [markdown]
# ### Heatmap Widget

# %%
# Set up dropdown widgets
parameter = widgets.Dropdown(
    options=sorted(df_data.parameter.unique()),
    description='Parameter:',
    disabled=False,
)

site_type = widgets.Dropdown(
    options=sorted(df_data.query(f"parameter == '{parameter.value}'")["wb_type"].unique()),
    description='Site Type:',
    disabled=False,
)

# Callback to update site_type options based on selected parameter 
def handle_parameter_change(change):
    site_type.options = sorted(df_data.query(f"parameter == '{parameter.value}'")["wb_type"].unique())

# Plotting callback 
def heatmap_selector(parameter, site_type):
    heatmap(df_counts.loc[parameter, site_type], f'{parameter} Counts by Site')

# Observe changes in parameter to update site types 
parameter.observe(handle_parameter_change, names="value")

# Set up interactive widgets 
widgets.interact(heatmap_selector, parameter=parameter, site_type=site_type)
# Out:
# interactive(children=(Dropdown(description='Parameter:', options=('Alkalinity', 'Calcium', 'Chloride', 'Chloro…
# <function __main__.heatmap_selector(parameter, site_type)>

# %%
# Summary table of counts 
# The table we will group by site, years, parameter, depth
df_param_count = df_data.groupby(['ww_id', df_data.index.year, 'parameter', 'depth']).size()

# %%
pd.set_option('display.max_rows', 1000)
print(df_param_count['WW016'])
pd.set_option('display.max_rows', 100)
# Out:
# date  parameter              depth
# 1990  Alkalinity             1.0       3
#       Calcium                1.0       3
#       Chloride               1.0       3
#       Chlorophyll a          1.0      13
#                              5.0       3
#       Dissolved Oxygen       1.0       2
#                              5.0      13
#       Magnesium              1.0       3
#       Nitrate + Nitrite      1.0       3
#       Phosphorus, Dissolved  1.0       3
#       Phosphorus, Total      1.0       3
#       Sodium                 1.0       3
#       Temperature            1.0      14
#                              5.0      14
#       pH                     1.0       3
# 1991  Alkalinity             1.0       3
#       Calcium                1.0       3
#       Chloride               1.0       3
#       Chlorophyll a          1.0      14
#                              5.0       3
#       Dissolved Oxygen       1.0       3
#                              5.0      14
#       E.coli                 0.5       3
#       Magnesium              1.0       3
#       Nitrate + Nitrite      1.0       3
#       Phosphorus, Dissolved  1.0       3
#       Phosphorus, Total      1.0       3
#       Sodium                 1.0       3
#       Temperature            1.0      11
#                              5.0      11
#       pH                     1.0       3
# 1992  Alkalinity             1.0       3
#       Calcium                1.0       3
#       Chloride               1.0       3
#       Chlorophyll a          1.0      15
#                              5.0       3
#       Dissolved Oxygen       1.0      11
#                              5.0      10
#       E.coli                 0.5       3
#       Magnesium              1.0       3
#       Phosphorus, Total      1.0       3
#       Sodium                 1.0       3
#       Temperature            1.0      14
#                              5.0      12
#       pH                     1.0       3
# 1993  Alkalinity             1.0       3
#                              5.0       3
#       Calcium                1.0       3
#       Chloride               1.0       3
#                              5.0       3
#       Chlorophyll a          1.0       7
#                              5.0       2
#       Dissolved Oxygen       1.0       8
#                              5.0       8
#       E.coli                 0.5       3
#       Fecal Coliform         0.5       3
#       Nitrate + Nitrite      1.0       3
#                              5.0       2
#       Nitrogen, Total        1.0       2
#                              5.0       2
#       Phosphorus, Dissolved  1.0       3
#                              5.0       2
#       Phosphorus, Total      1.0       3
#                              5.0       3
#       Sodium                 1.0       3
#       Temperature            1.0      12
#                              5.0      12
#       pH                     1.0       3
#                              5.0       3
# 1994  Alkalinity             1.0       3
#       Calcium                1.0       3
#       Chloride               1.0       2
#       Chlorophyll a          1.0      13
#                              5.0       1
#       Dissolved Oxygen       1.0      11
#                              5.0      12
#       E.coli                 0.5       3
#       Fecal Coliform         0.5       3
#       Nitrate + Nitrite      1.0       1
#                              5.0       3
#       Nitrogen, Total        1.0       1
#                              5.0       1
#       Phosphorus, Dissolved  1.0       3
#                              5.0       2
#       Phosphorus, Total      1.0       3
#                              5.0       2
#       Sodium                 1.0       3
#       Temperature            1.0      11
#                              5.0      12
#       pH                     1.0       3
# 1995  Alkalinity             1.0       2
#       Calcium                1.0       2
#       Chloride               1.0       2
#       Chlorophyll a          1.0       7
#       Dissolved Oxygen       1.0       8
#                              4.0       1
#                              5.0       7
#       E.coli                 0.5       2
#       Fecal Coliform         0.5       2
#       Nitrate + Nitrite      1.0       2
#       Nitrogen, Total        1.0       1
#                              5.0       1
#       Phosphorus, Dissolved  1.0       2
#       Phosphorus, Total      1.0       2
#                              5.0       1
#       Sodium                 1.0       2
#       Temperature            1.0       8
#                              4.0       1
#                              5.0       7
#       pH                     1.0       2
# 1996  Alkalinity             1.0       2
#       Chloride               1.0       2
#       Chlorophyll a          1.0      11
#       Dissolved Oxygen       1.0      11
#                              5.0       1
#                              6.0      10
#       Nitrate + Nitrite      1.0       3
#       Nitrogen, Total        1.0       2
#                              5.0       2
#       Phosphorus, Dissolved  1.0       3
#       Phosphorus, Total      1.0       2
#                              5.0       3
#       Temperature            1.0      11
#                              5.0       1
#                              6.0      10
#       pH                     1.0       2
# 1997  Alkalinity             1.0       3
#                              5.0       2
#       Chloride               1.0       2
#       Chlorophyll a          1.0      10
#       Dissolved Oxygen       1.0      10
#                              5.0       1
#                              6.0       9
#       Nitrate + Nitrite      1.0       3
#       Nitrogen, Ammonia      1.0       2
#       Nitrogen, Total        1.0       3
#                              5.0       3
#       Phosphorus, Dissolved  1.0       3
#       Phosphorus, Total      1.0       3
#                              5.0       3
#       Temperature            1.0      10
#                              5.0       1
#                              6.0       9
#       pH                     1.0       3
#                              5.0       2
# 1998  Alkalinity             1.0       4
#       Chloride               1.0       3
#       Chlorophyll a          1.0       6
#       Dissolved Oxygen       1.0       7
#                              3.0       1
#                              5.0       1
#                              6.0       5
#       Nitrate + Nitrite      1.0       3
#       Nitrogen, Ammonia      1.0       2
#       Nitrogen, Total        1.0       3
#                              5.0       3
#       Phosphorus, Dissolved  1.0       3
#       Phosphorus, Total      1.0       3
#                              5.0       3
#       Temperature            1.0       7
#                              3.0       1
#                              5.0       1
#                              6.0       5
#       pH                     1.0       4
# 1999  Alkalinity             1.0       3
#       Chloride               1.0       3
#                              5.0       2
#       Chlorophyll a          1.0       9
#       Dissolved Oxygen       1.0      10
#                              6.0      10
#       Nitrate + Nitrite      1.0       3
#                              5.0       1
#       Nitrogen, Ammonia      1.0       3
#                              5.0       2
#       Nitrogen, Total        1.0       3
#                              5.0       3
#       Phosphorus, Dissolved  1.0       3
#                              5.0       2
#       Phosphorus, Total      1.0       3
#                              5.0       3
#       Temperature            1.0      22
#                              5.0       1
#                              6.0       9
#       pH                     1.0       3
#                              5.0       1
# 2000  Alkalinity             1.0       3
#       Chloride               1.0       3
#       Chlorophyll a          1.0      11
#       Dissolved Oxygen       1.0      11
#                              6.0      12
#       Nitrate + Nitrite      1.0       3
#                              5.0       1
#       Nitrogen, Ammonia      1.0       3
#                              5.0       1
#       Nitrogen, Total        1.0       3
#                              5.0       3
#       Phosphorus, Dissolved  1.0       3
#                              5.0       1
#       Phosphorus, Total      1.0       3
#                              5.0       3
#       Temperature            1.0      22
#                              6.0      12
#       pH                     1.0       3
#                              5.0       1
# 2001  Alkalinity             1.0       3
#       Chloride               1.0       2
#                              5.0       2
#       Chlorophyll a          1.0      14
#       Dissolved Oxygen       1.0      14
#                              6.0      14
#       Nitrate + Nitrite      1.0       3
#                              5.0       3
#       Nitrogen, Ammonia      1.0       2
#                              5.0       2
#       Nitrogen, Total        1.0       3
#                              5.0       3
#       Phosphorus, Dissolved  1.0       3
#                              5.0       3
#       Phosphorus, Total      1.0       3
#                              5.0       3
#       Temperature            1.0      28
#                              6.0      14
#       pH                     1.0       3
#                              5.0       2
# 2002  Alkalinity             1.0       3
#       Chloride               1.0       2
#                              6.0       2
#       Chlorophyll a          1.0      12
#       Dissolved Oxygen       1.0      12
#                              6.0      12
#       E.coli                 0.5       3
#       Fecal Coliform         0.5       3
#       Nitrate + Nitrite      1.0       3
#                              6.0       3
#       Nitrogen, Ammonia      1.0       2
#                              6.0       3
#       Nitrogen, Total        1.0       3
#                              6.0       3
#       Phosphorus, Dissolved  1.0       3
#                              6.0       3
#       Phosphorus, Total      1.0       3
#                              6.0       3
#       Temperature            1.0      24
#                              6.0      12
#       pH                     1.0       3
#                              6.0       3
# 2003  Alkalinity             1.0       3
#       Chloride               1.0       2
#                              6.0       1
#       Chlorophyll a          1.0      13
#       Dissolved Oxygen       1.0      12
#                              6.0      12
#       E.coli                 0.5       3
#       Fecal Coliform         0.5       3
#       Nitrate + Nitrite      1.0       3
#                              6.0       3
#       Nitrogen, Ammonia      1.0       1
#                              6.0       3
#       Nitrogen, Total        1.0       3
#                              6.0       3
#       Phosphorus, Dissolved  1.0       3
#                              6.0       3
#       Phosphorus, Total      1.0       3
#                              6.0       3
#       Temperature            1.0      23
#                              6.0      11
#       pH                     1.0       3
#                              6.0       2
# 2004  Alkalinity             1.0       3
#       Chloride               1.0       2
#                              6.0       2
#       Chlorophyll a          1.0       9
#       Dissolved Oxygen       1.0       9
#                              6.0       9
#       E.coli                 0.5       3
#       Fecal Coliform         0.5       3
#       Nitrate + Nitrite      1.0       3
#                              6.0       3
#       Nitrogen, Ammonia      1.0       1
#                              6.0       3
#       Nitrogen, Total        1.0       3
#                              6.0       3
#       Phosphorus, Dissolved  1.0       3
#                              6.0       3
#       Phosphorus, Total      1.0       3
#                              6.0       3
#       Temperature            1.0      19
#                              6.0      10
#       pH                     1.0       3
#                              6.0       3
# 2005  Alkalinity             1.0       4
#       Chloride               1.0       3
#                              6.0       3
#       Chlorophyll a          1.0       8
#       Dissolved Oxygen       1.0       8
#                              6.0       8
#       Fecal Coliform         0.5       4
#       Nitrate + Nitrite      1.0       4
#                              6.0       4
#       Nitrogen, Ammonia      1.0       4
#                              6.0       4
#       Nitrogen, Total        1.0       4
#                              6.0       4
#       Phosphorus, Dissolved  1.0       4
#                              6.0       4
#       Phosphorus, Total      1.0       4
#                              6.0       4
#       Temperature            1.0      16
#                              6.0       8
#       pH                     1.0       4
#                              6.0       4
# 2006  Alkalinity             1.0       3
#       Chloride               1.0       2
#                              6.0       2
#       Chlorophyll a          1.0       8
#       Dissolved Oxygen       1.0       8
#                              6.0       8
#       Enterococci            0.5       3
#       Nitrate + Nitrite      1.0       3
#                              6.0       3
#       Nitrogen, Ammonia      1.0       3
#                              6.0       3
#       Nitrogen, Total        1.0       3
#                              6.0       3
#       Phosphorus, Dissolved  1.0       3
#                              6.0       3
#       Phosphorus, Total      1.0       3
#                              6.0       3
#       Temperature            1.0      16
#                              6.0       8
#       pH                     1.0       3
#                              6.0       3
# 2007  Alkalinity             1.0       3
#       Chloride               1.0       2
#                              6.0       2
#       Chlorophyll a          1.0       9
#       Dissolved Oxygen       1.0       7
#                              6.0       7
#       Enterococci            0.5       3
#       Nitrate + Nitrite      1.0       3
#                              6.0       3
#       Nitrogen, Ammonia      1.0       3
#                              6.0       3
#       Nitrogen, Total        1.0       3
#                              6.0       3
#       Phosphorus, Dissolved  1.0       3
#                              6.0       3
#       Phosphorus, Total      1.0       3
#                              6.0       3
#       Temperature            1.0      15
#                              6.0       7
#       pH                     1.0       3
#                              6.0       3
# 2008  Alkalinity             1.0       5
#       Chloride               1.0       2
#                              6.0       2
#       Chlorophyll a          1.0       9
#       Dissolved Oxygen       1.0       8
#                              6.0       8
#       Enterococci            0.5       5
#       Nitrate + Nitrite      1.0       5
#                              6.0       5
#       Nitrogen, Ammonia      1.0       5
#                              6.0       5
#       Nitrogen, Total        1.0       5
#                              6.0       5
#       Phosphorus, Dissolved  1.0       5
#                              6.0       4
#       Phosphorus, Total      1.0       5
#                              6.0       5
#       Temperature            1.0      14
#                              6.0       6
#       pH                     1.0       5
#                              6.0       5
# 2009  Alkalinity             1.0       3
#       Chloride               1.0       2
#                              6.0       2
#       Chlorophyll a          1.0       5
#       Dissolved Oxygen       1.0       7
#                              6.0       7
#       Enterococci            0.5       3
#       Nitrate + Nitrite      1.0       3
#                              6.0       3
#       Nitrogen, Ammonia      1.0       3
#                              6.0       3
#       Nitrogen, Total        1.0       3
#                              6.0       3
#       Phosphorus, Dissolved  1.0       3
#                              6.0       3
#       Phosphorus, Total      1.0       3
#                              6.0       3
#       Temperature            1.0      12
#                              6.0       5
#       pH                     1.0       3
#                              6.0       3
# 2010  Alkalinity             1.0       4
#       Chloride               1.0       1
#                              6.0       1
#       Chlorophyll a          1.0       6
#       Dissolved Oxygen       1.0       6
#                              6.0       6
#       Enterococci            0.5       3
#       Nitrate + Nitrite      1.0       4
#                              6.0       4
#       Nitrogen, Ammonia      1.0       4
#                              6.0       4
#       Nitrogen, Total        1.0       4
#                              6.0       4
#       Phosphorus, Dissolved  1.0       4
#                              6.0       4
#       Phosphorus, Total      1.0       4
#                              6.0       4
#       Temperature            1.0      12
#                              6.0       6
#       pH                     1.0       4
#                              6.0       3
# 2011  Chloride               1.0       2
#                              6.0       2
#       Chlorophyll a          1.0       6
#       Dissolved Oxygen       1.0       6
#                              6.0       6
#       Enterococci            0.5       3
#       Nitrate + Nitrite      1.0       3
#                              6.0       3
#       Nitrogen, Ammonia      1.0       3
#                              6.0       3
#       Nitrogen, Total        1.0       3
#                              6.0       3
#       Phosphorus, Dissolved  1.0       3
#                              6.0       3
#       Phosphorus, Total      1.0       3
#                              6.0       3
#       Temperature            1.0      10
#                              6.0       5
# 2012  Alkalinity             1.0       4
#       Chloride               1.0       2
#                              6.0       2
#       Chlorophyll a          1.0       4
#       Dissolved Oxygen       1.0       4
#                              6.0       4
#       Enterococci            0.5       3
#       Nitrate + Nitrite      1.0       3
#                              6.0       3
#       Nitrogen, Ammonia      1.0       3
#                              6.0       3
#       Nitrogen, Total        1.0       3
#                              6.0       3
#       Phosphorus, Dissolved  1.0       3
#                              6.0       3
#       Phosphorus, Total      1.0       3
#                              6.0       3
#       Temperature            1.0       8
#                              6.0       4
#       pH                     1.0       3
#                              6.0       3
# 2013  Alkalinity             1.0       4
#       Chloride               1.0       2
#                              4.0       1
#                              6.0       1
#       Chlorophyll a          1.0       4
#       Dissolved Oxygen       1.0       4
#                              4.0       1
#                              6.0       3
#       E.coli                 0.5       1
#       Enterococci            0.5       2
#       Nitrate + Nitrite      1.0       3
#                              4.0       1
#                              6.0       2
#       Nitrogen, Ammonia      1.0       3
#                              4.0       1
#                              6.0       2
#       Nitrogen, Total        1.0       3
#                              4.0       1
#                              6.0       2
#       Phosphorus, Dissolved  1.0       3
#                              4.0       1
#                              6.0       2
#       Phosphorus, Total      1.0       3
#                              4.0       1
#                              6.0       2
#       Temperature            1.0       7
#                              5.0       1
#                              6.0       2
#       Total coliform         1.0       1
#       pH                     1.0       4
#                              4.0       1
#                              6.0       2
# 2014  Alkalinity             1.0       3
#       Chlorophyll a          1.0       3
#       Dissolved Oxygen       1.0       3
#                              6.0       3
#       Enterococci            0.5       3
#       Nitrate + Nitrite      1.0       3
#                              6.0       3
#       Nitrogen, Ammonia      1.0       3
#                              5.0       1
#                              6.0       2
#       Nitrogen, Total        1.0       3
#                              6.0       3
#       Phosphorus, Dissolved  1.0       3
#                              6.0       3
#       Phosphorus, Total      1.0       3
#                              6.0       3
#       Temperature            1.0       6
#                              6.0       3
#       pH                     1.0       4
#                              6.0       3
# 2015  Alkalinity             1.0       2
#       Chloride               1.0       1
#                              6.0       1
#       Chlorophyll a          1.0       5
#       Dissolved Oxygen       1.0       5
#                              6.0       5
#       Enterococci            0.5       4
#       Nitrate + Nitrite      1.0       3
#                              6.0       3
#       Nitrogen, Ammonia      1.0       3
#                              6.0       3
#       Nitrogen, Total        1.0       3
#                              6.0       3
#       Phosphorus, Dissolved  1.0       3
#                              6.0       3
#       Phosphorus, Total      1.0       3
#                              6.0       3
#       Temperature            1.0       8
#                              6.0       4
#       pH                     1.0       2
#                              6.0       2
# 2016  Alkalinity             1.0       4
#       Chloride               1.0       2
#                              5.0       1
#                              6.0       1
#       Chlorophyll a          1.0       4
#       Dissolved Oxygen       1.0       4
#                              5.0       2
#                              6.0       2
#       Enterococci            0.5       4
#       Nitrate + Nitrite      1.0       4
#                              5.0       2
#                              6.0       2
#       Nitrogen, Ammonia      1.0       4
#                              5.0       2
#                              6.0       2
#       Nitrogen, Total        1.0       4
#                              5.0       2
#                              6.0       2
#       Phosphorus, Dissolved  1.0       4
#                              5.0       2
#                              6.0       1
#       Phosphorus, Total      1.0       4
#                              5.0       2
#                              6.0       1
#       Temperature            1.0       8
#                              5.0       2
#                              6.0       2
#       pH                     1.0       4
#                              5.0       2
#                              6.0       2
# 2017  Alkalinity             1.0       4
#       Chloride               1.0       2
#                              4.0       1
#                              6.0       1
#       Chlorophyll a          1.0       3
#       Dissolved Oxygen       1.0       3
#                              4.0       1
#                              6.0       2
#       Enterococci            0.5       3
#       Nitrate + Nitrite      1.0       3
#                              4.0       1
#                              6.0       2
#       Nitrogen, Ammonia      1.0       3
#                              4.0       1
#                              6.0       2
#       Nitrogen, Total        1.0       3
#                              4.0       1
#                              6.0       2
#       Phosphorus, Dissolved  1.0       3
#                              4.0       1
#                              6.0       2
#       Phosphorus, Total      1.0       3
#                              4.0       1
#                              6.0       2
#       Temperature            1.0       5
#                              4.0       1
#                              6.0       2
#       pH                     1.0       4
#                              4.0       1
#                              6.0       2
# 2018  Alkalinity             1.0       4
#       Chloride               1.0       4
#                              4.0       2
#                              5.0       2
#       Chlorophyll a          1.0       3
#       Dissolved Oxygen       1.0       4
#                              4.0       2
#                              5.0       2
#       Enterococci            0.5       4
#       Nitrate + Nitrite      1.0       4
#                              4.0       2
#                              5.0       2
#       Nitrogen, Ammonia      1.0       4
#                              4.0       2
#                              5.0       2
#       Nitrogen, Total        1.0       4
#                              4.0       2
#                              5.0       2
#       Phosphorus, Dissolved  1.0       4
#                              4.0       2
#                              5.0       2
#       Phosphorus, Total      1.0       4
#                              4.0       2
#                              5.0       2
#       Temperature            1.0       7
#                              4.0       2
#                              5.0       2
#       pH                     1.0       4
#                              4.0       2
#                              5.0       2
# 2019  Alkalinity             1.0       4
#       Chloride               1.0       2
#                              4.5       1
#                              5.5       1
#       Chlorophyll a          1.0       4
#       Dissolved Oxygen       1.0       4
#                              4.5       1
#                              5.2       1
#                              5.5       1
#                              5.8       1
#       Enterococci            0.5       4
#       Nitrate + Nitrite      1.0       4
#                              4.5       1
#                              5.2       1
#                              5.5       1
#                              5.8       1
#       Nitrogen, Ammonia      1.0       4
#                              4.5       1
#                              5.2       1
#                              5.5       1
#                              5.8       1
#       Nitrogen, Total        1.0       4
#                              4.5       1
#                              5.2       1
#                              5.5       1
#                              5.8       1
#       Phosphorus, Dissolved  1.0       4
#                              4.5       1
#                              5.2       1
#                              5.5       1
#                              5.8       1
#       Phosphorus, Total      1.0       4
#                              4.5       1
#                              5.2       1
#                              5.5       1
#                              5.8       1
#       Temperature            0.1       3
#                              1.0       4
#                              4.5       1
#                              5.2       1
#                              5.5       1
#                              5.8       1
#       pH                     1.0       4
#                              4.5       1
#                              5.0       1
#                              5.5       1
#                              5.8       1
# 2020  Alkalinity             1.0       4
#       Chloride               1.0       2
#                              4.5       1
#                              5.8       1
#       Chlorophyll a          1.0       8
#       Dissolved Oxygen       1.0       9
#                              4.5       1
#                              5.0       1
#                              5.5       7
#                              5.8       1
#       Enterococci            0.5       3
#       Nitrate + Nitrite      1.0       4
#                              4.5       1
#                              5.0       1
#                              5.5       1
#                              5.8       1
#       Nitrogen, Ammonia      1.0       4
#                              4.5       1
#                              5.0       1
#                              5.5       1
#                              5.8       1
#       Nitrogen, Total        1.0       4
#                              4.5       1
#                              5.0       1
#                              5.5       1
#                              5.8       1
#       Phosphorus, Dissolved  1.0       4
#                              4.5       1
#                              5.0       1
#                              5.5       1
#                              5.8       1
#       Phosphorus, Total      1.0       4
#                              4.5       1
#                              5.0       1
#                              5.5       1
#                              5.8       1
#       Temperature            0.1       2
#                              1.0      15
#                              4.5       1
#                              5.0       1
#                              5.5      12
#                              5.8       1
#       pH                     1.0       4
#                              4.5       1
#                              5.5       1
#                              5.8       1
# 2021  Alkalinity             1.0       4
#       Chloride               1.0       2
#                              5.5       2
#       Chlorophyll a          1.0      12
#       Dissolved Oxygen       1.0      22
#                              5.0       1
#                              5.5       8
#       Enterococci            0.5       6
#       Nitrate + Nitrite      1.0       4
#                              5.5       4
#       Nitrogen, Ammonia      1.0       4
#                              5.5       4
#       Nitrogen, Total        1.0       4
#                              5.5       4
#       Phosphorus, Dissolved  1.0       4
#                              5.5       4
#       Phosphorus, Total      1.0       4
#                              5.5       4
#       Temperature            0.1      23
#                              1.0      23
#                              5.0       2
#                              5.5       8
#       pH                     1.0       4
#                              5.5       4
# dtype: int64

# %% [markdown]
# # III. Mapping file construction
# Make a CSV to import into GIS.
# * Each site will be a point
# * Attributes: Site code, Site name, Years measured, Parameters measured, Depths Measured, X, Y

# %%
df_mapping = (
    df_data
    .reset_index()
    .groupby(['ww_id'])
    .agg({
        'parameter': lambda x: sorted(x.unique()),
        'date': lambda x: list(x.dt.year.unique()),
        'depth': lambda x: sorted(x.dropna().unique()),
}))
df_mapping = (df_mapping
              .merge(df_site.loc[:, ['ww_id', 'wbid', 'wb_type', 'site_descr', 'lat_dd', 'lon_dd']], 
                     left_index=True, 
                     right_on='ww_id', 
                     how='left'
                    )
              .loc[:, ['ww_id', 'wbid', 'wb_type', 'site_descr', 'lat_dd', 'lon_dd', 'parameter', 'date', 'depth']]
              .rename(columns={'parameter': 'parameters', 'date': 'years', 'depth': 'depths'})
             )
df_mapping
# Out:
#     ww_id            wbid          wb_type  \
# 0   WW016   RI0002007L-02       Reservoir
# 1   WW024   RI0002007L-06       Reservoir
# 2   WW046   RI0002007L-03       Reservoir
# 3   WW052   RI0002007L-07       Reservoir
# 4   WW061   RI0002007L-04       Reservoir
# 5   WW065   RI0002007L-08       Reservoir
# 6   WW113  RI0002007R-10A       Reservoir
# 7   WW114   RI0002007R-03  Stream or river
# 8   WW123   RI0002007R-15  Stream or river
# 9   WW124   RI0002007R-15  Stream or river
# 10  WW125   RI0002007R-15  Stream or river
# 11  WW126   RI0002007R-15  Stream or river
# 12  WW144   RI0002007L-05       Reservoir
# 13  WW153   RI0002007L-08       Reservoir
# 14  WW201   RI0002007L-01     Lake or Pond
# 15  WW226  RI0002007R-10C  Stream or river
# 16  WW227  RI0002007R-10D  Stream or river
# 17  WW238   RI0002007R-11  Stream or river
# 18  WW239   RI0002007R-02  Stream or river
# 19  WW240   RI0002007R-14  Stream or river
# 20  WW241   RI0002007R-14  Stream or river
# 21  WW308  RI0002007R-10D          Estuary
# 22  WW437  RI0002007R-10C       Reservoir
# 23  WW508  RI0002007R-10C  Stream or river
# 24  WW518   RI0002007R-14  Stream or river
# 25  WW635             NaN  Stream or river
# 26  WW679             NaN  Stream or river
# 27  WW680             NaN  Stream or river
#
#                                            site_descr     lat_dd     lon_dd  \
# 0                                   Georgiaville Pond  41.892783 -71.511331
# 1                             Lower Sprague Reservoir  41.887806 -71.548376
# 2                                   Slack's Reservoir  41.859528 -71.551750
# 3                                     Stillwater Pond  41.908342 -71.527331
# 4                                  Waterman Reservoir  41.881519 -71.589489
# 5              Woonasquatucket Reservoir (Stump Pond)  41.906078 -71.544722
# 6    Georgiaville @ Capron Pond/Woonasquatucket River  41.902792 -71.521688
# 7                  Georgiaville @ Harris/Harris Brook  41.899054 -71.510030
# 8   Slack's Tributary 1 (A - Northwest corner - cu...  41.866375 -71.558561
# 9   Slack's Tributary 2 (B - SW cove - drainage fr...  41.859348 -71.557825
# 10  Slack's Tributary 3 (C - Outlet of stream cros...  41.855697 -71.556795
# 11  Slack's Tributary 4 (D - Southeast cove - 17" ...  41.855578 -71.549621
# 12                            Upper Sprague Reservoir  41.892947 -71.564222
# 13                Woonasquatucket Reservoir-South end  41.892444 -71.538289
# 14                                       Hawkins Pond  41.860291 -71.544422
# 15               Woonasquatucket River @ Cricket Park  41.865593 -71.492459
# 16              Woonasquatucket River @ Donigian Park  41.822595 -71.440308
# 17      Waterman Tributary @ Rte 44 (Nine Foot Brook)  41.883532 -71.582255
# 18       Waterman Tributary @ Saw Mill (Cutler Brook)  41.884593 -71.599831
# 19                   Waterman Tributary @ Golf Course  41.884085 -71.591567
# 20                       Waterman Tributary @ Aldrich  41.872043 -71.588646
# 21            Woonasquatucket River @ Waterplace Park  41.826576 -71.414062
# 22             Woonasquatucket River @ Greystone Pond  41.866175 -71.492738
# 23                Woonasquatucket River @ Manton Ave.  41.832995 -71.470563
# 24         Waterman Tributary Upstream of Golf Course  41.887282 -71.591147
# 25              Woonasquatucket River @ Whipple Field  41.883749 -71.504435
# 26                               Geov Trib – Sweet Rd  41.890414 -71.514129
# 27                       Geoville Trib @ Below Harris  41.894566 -71.507241
#
#                                            parameters  \
# 0   [Alkalinity, Calcium, Chloride, Chlorophyll a,...
# 1   [Alkalinity, Calcium, Chloride, Chlorophyll a,...
# 2   [Alkalinity, Calcium, Chloride, Chlorophyll a,...
# 3   [Alkalinity, Calcium, Chloride, Chlorophyll a,...
# 4   [Alkalinity, Calcium, Chloride, Chlorophyll a,...
# 5   [Alkalinity, Calcium, Chloride, Chlorophyll a,...
# 6   [Chloride, E.coli, Enterococci, Fecal Coliform...
# 7   [Chloride, E.coli, Enterococci, Fecal Coliform...
# 8   [Chloride, E.coli, Enterococci, Fecal Coliform...
# 9   [Alkalinity, Chloride, E.coli, Enterococci, Fe...
# 10  [Chloride, E.coli, Enterococci, Fecal Coliform...
# 11  [Chloride, E.coli, Enterococci, Fecal Coliform...
# 12  [Alkalinity, Calcium, Chloride, Chlorophyll a,...
# 13  [Alkalinity, Calcium, Chloride, Chlorophyll a,...
# 14  [Alkalinity, Chloride, Chlorophyll a, Depth, E...
# 15  [Chloride, Dissolved Oxygen, Enterococci, Feca...
# 16  [Chloride, Depth, Dissolved Oxygen, E.coli, En...
# 17  [Chloride, E.coli, Enterococci, Fecal Coliform...
# 18  [Chloride, E.coli, Enterococci, Fecal Coliform...
# 19  [Chloride, E.coli, Enterococci, Fecal Coliform...
# 20  [Chloride, E.coli, Enterococci, Fecal Coliform...
# 21  [Chloride, Depth, Dissolved Oxygen, Enterococc...
# 22  [Chloride, Depth, Dissolved Oxygen, Enterococc...
# 23  [Chloride, Depth, Dissolved Oxygen, Enterococc...
# 24                                      [Enterococci]
# 25  [Chloride, Depth, Dissolved Oxygen, Enterococc...
# 26  [Enterococci, Nitrate + Nitrite, Nitrogen, Amm...
# 27  [Chloride, Enterococci, Nitrate + Nitrite, Nit...
#
#                                                 years  \
# 0   [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 1   [1994, 1995, 1996, 1997, 1998, 2000, 2001, 200...
# 2   [1990, 1991, 1992, 1994, 1995, 1996, 1997, 199...
# 3   [1990, 1991, 1992, 1994, 1996, 1997, 1998, 199...
# 4   [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 5   [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 6   [1995, 1996, 1997, 1998, 1999, 2000, 2001, 200...
# 7   [1996, 1997, 1998, 1999, 2000, 2001, 2002, 200...
# 8   [1996, 1997, 1998, 1999, 2000, 2001, 2002, 200...
# 9   [1996, 1997, 1998, 1999, 2000, 2001, 2002, 200...
# 10  [1996, 1997, 1998, 1999, 2000, 2001, 2002, 200...
# 11  [1998, 1999, 2000, 2001, 2002, 2003, 2004, 200...
# 12                                 [1991, 1992, 1993]
# 13         [1994, 1995, 1996, 1997, 1998, 1999, 2000]
# 14  [2002, 2003, 2004, 2005, 2006, 2007, 2008, 200...
# 15                                 [2005, 2006, 2007]
# 16  [1995, 2003, 2004, 2005, 2006, 2007, 2008, 200...
# 17  [2002, 2003, 2004, 2005, 2006, 2007, 2008, 200...
# 18  [2002, 2003, 2004, 2005, 2006, 2007, 2008, 200...
# 19  [2004, 2005, 2006, 2007, 2008, 2009, 2010, 201...
# 20  [2004, 2005, 2006, 2007, 2008, 2009, 2010, 201...
# 21  [2008, 2009, 2010, 2011, 2012, 2013, 2014, 201...
# 22  [2008, 2009, 2010, 2011, 2012, 2013, 2014, 201...
# 23                                             [2011]
# 24                                             [2010]
# 25                     [2017, 2018, 2019, 2020, 2021]
# 26                                       [2019, 2020]
# 27                                       [2020, 2021]
#
#                                                depths
# 0   [0.1, 0.5, 1.0, 3.0, 4.0, 4.5, 5.0, 5.2, 5.5, ...
# 1                                          [0.5, 1.0]
# 2            [0.0, 0.1, 0.5, 1.0, 2.0, 3.0, 4.0, 8.0]
# 3                                [0.0, 0.5, 1.0, 3.0]
# 4                           [0.0, 0.1, 0.5, 1.0, 2.0]
# 5                                [0.0, 0.5, 1.0, 3.0]
# 6                                               [0.2]
# 7                                               [0.2]
# 8                                          [0.0, 0.2]
# 9                                          [0.0, 0.2]
# 10                                         [0.0, 0.2]
# 11                                         [0.0, 0.2]
# 12                               [0.5, 1.0, 4.0, 5.0]
# 13                                    [0.0, 0.5, 1.0]
# 14                                    [0.1, 0.5, 1.0]
# 15                                         [0.0, 0.3]
# 16  [0.0, 0.1, 0.15, 0.2, 0.3, 0.4, 0.5, 1.0, 1.8,...
# 17                                         [0.0, 0.2]
# 18                                         [0.0, 0.2]
# 19                                         [0.0, 0.2]
# 20                                         [0.0, 0.2]
# 21          [0.0, 0.1, 0.15, 0.2, 0.3, 0.5, 1.0, 2.0]
# 22  [0.0, 0.1, 0.2, 0.24, 0.25, 0.27, 0.3, 0.31, 0...
# 23                                    [0.0, 0.4, 0.5]
# 24                                              [0.2]
# 25                   [0.0, 0.1, 0.15, 0.18, 0.2, 0.3]
# 26                                              [0.2]
# 27                                              [0.2]

# %%
def list_to_string(l: list, wrap: int = 4):
    output_str = ''
    l_strings = [str(s).replace(',', '') for s in l]
    for i, item in enumerate(l_strings):
        output_str += f'{item}'
        if i+1 != len(l_strings):
            output_str += ', '
            if (i+1)%wrap == 0:
                output_str += '<br>'

    return output_str

# Convert lists to strings for maping display
df_mapping_out = (
    df_mapping
    .assign(
        parameters=df_mapping['parameters'].apply(list_to_string),
        years=df_mapping['years'].apply(partial(list_to_string, wrap=8)),
        depths=df_mapping['depths'].apply(partial(list_to_string, wrap=10))
    ))
df_mapping_out
# Out:
#     ww_id            wbid          wb_type  \
# 0   WW016   RI0002007L-02       Reservoir
# 1   WW024   RI0002007L-06       Reservoir
# 2   WW046   RI0002007L-03       Reservoir
# 3   WW052   RI0002007L-07       Reservoir
# 4   WW061   RI0002007L-04       Reservoir
# 5   WW065   RI0002007L-08       Reservoir
# 6   WW113  RI0002007R-10A       Reservoir
# 7   WW114   RI0002007R-03  Stream or river
# 8   WW123   RI0002007R-15  Stream or river
# 9   WW124   RI0002007R-15  Stream or river
# 10  WW125   RI0002007R-15  Stream or river
# 11  WW126   RI0002007R-15  Stream or river
# 12  WW144   RI0002007L-05       Reservoir
# 13  WW153   RI0002007L-08       Reservoir
# 14  WW201   RI0002007L-01     Lake or Pond
# 15  WW226  RI0002007R-10C  Stream or river
# 16  WW227  RI0002007R-10D  Stream or river
# 17  WW238   RI0002007R-11  Stream or river
# 18  WW239   RI0002007R-02  Stream or river
# 19  WW240   RI0002007R-14  Stream or river
# 20  WW241   RI0002007R-14  Stream or river
# 21  WW308  RI0002007R-10D          Estuary
# 22  WW437  RI0002007R-10C       Reservoir
# 23  WW508  RI0002007R-10C  Stream or river
# 24  WW518   RI0002007R-14  Stream or river
# 25  WW635             NaN  Stream or river
# 26  WW679             NaN  Stream or river
# 27  WW680             NaN  Stream or river
#
#                                            site_descr     lat_dd     lon_dd  \
# 0                                   Georgiaville Pond  41.892783 -71.511331
# 1                             Lower Sprague Reservoir  41.887806 -71.548376
# 2                                   Slack's Reservoir  41.859528 -71.551750
# 3                                     Stillwater Pond  41.908342 -71.527331
# 4                                  Waterman Reservoir  41.881519 -71.589489
# 5              Woonasquatucket Reservoir (Stump Pond)  41.906078 -71.544722
# 6    Georgiaville @ Capron Pond/Woonasquatucket River  41.902792 -71.521688
# 7                  Georgiaville @ Harris/Harris Brook  41.899054 -71.510030
# 8   Slack's Tributary 1 (A - Northwest corner - cu...  41.866375 -71.558561
# 9   Slack's Tributary 2 (B - SW cove - drainage fr...  41.859348 -71.557825
# 10  Slack's Tributary 3 (C - Outlet of stream cros...  41.855697 -71.556795
# 11  Slack's Tributary 4 (D - Southeast cove - 17" ...  41.855578 -71.549621
# 12                            Upper Sprague Reservoir  41.892947 -71.564222
# 13                Woonasquatucket Reservoir-South end  41.892444 -71.538289
# 14                                       Hawkins Pond  41.860291 -71.544422
# 15               Woonasquatucket River @ Cricket Park  41.865593 -71.492459
# 16              Woonasquatucket River @ Donigian Park  41.822595 -71.440308
# 17      Waterman Tributary @ Rte 44 (Nine Foot Brook)  41.883532 -71.582255
# 18       Waterman Tributary @ Saw Mill (Cutler Brook)  41.884593 -71.599831
# 19                   Waterman Tributary @ Golf Course  41.884085 -71.591567
# 20                       Waterman Tributary @ Aldrich  41.872043 -71.588646
# 21            Woonasquatucket River @ Waterplace Park  41.826576 -71.414062
# 22             Woonasquatucket River @ Greystone Pond  41.866175 -71.492738
# 23                Woonasquatucket River @ Manton Ave.  41.832995 -71.470563
# 24         Waterman Tributary Upstream of Golf Course  41.887282 -71.591147
# 25              Woonasquatucket River @ Whipple Field  41.883749 -71.504435
# 26                               Geov Trib – Sweet Rd  41.890414 -71.514129
# 27                       Geoville Trib @ Below Harris  41.894566 -71.507241
#
#                                            parameters  \
# 0   Alkalinity, Calcium, Chloride, Chlorophyll a, ...
# 1   Alkalinity, Calcium, Chloride, Chlorophyll a, ...
# 2   Alkalinity, Calcium, Chloride, Chlorophyll a, ...
# 3   Alkalinity, Calcium, Chloride, Chlorophyll a, ...
# 4   Alkalinity, Calcium, Chloride, Chlorophyll a, ...
# 5   Alkalinity, Calcium, Chloride, Chlorophyll a, ...
# 6   Chloride, E.coli, Enterococci, Fecal Coliform,...
# 7   Chloride, E.coli, Enterococci, Fecal Coliform,...
# 8   Chloride, E.coli, Enterococci, Fecal Coliform,...
# 9   Alkalinity, Chloride, E.coli, Enterococci, <br...
# 10  Chloride, E.coli, Enterococci, Fecal Coliform,...
# 11  Chloride, E.coli, Enterococci, Fecal Coliform,...
# 12  Alkalinity, Calcium, Chloride, Chlorophyll a, ...
# 13  Alkalinity, Calcium, Chloride, Chlorophyll a, ...
# 14  Alkalinity, Chloride, Chlorophyll a, Depth, <b...
# 15  Chloride, Dissolved Oxygen, Enterococci, Fecal...
# 16  Chloride, Depth, Dissolved Oxygen, E.coli, <br...
# 17  Chloride, E.coli, Enterococci, Fecal Coliform,...
# 18  Chloride, E.coli, Enterococci, Fecal Coliform,...
# 19  Chloride, E.coli, Enterococci, Fecal Coliform,...
# 20  Chloride, E.coli, Enterococci, Fecal Coliform,...
# 21  Chloride, Depth, Dissolved Oxygen, Enterococci...
# 22  Chloride, Depth, Dissolved Oxygen, Enterococci...
# 23  Chloride, Depth, Dissolved Oxygen, Enterococci...
# 24                                        Enterococci
# 25  Chloride, Depth, Dissolved Oxygen, Enterococci...
# 26  Enterococci, Nitrate + Nitrite, Nitrogen Ammon...
# 27  Chloride, Enterococci, Nitrate + Nitrite, Nitr...
#
#                                                 years  \
# 0   1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997...
# 1   1994, 1995, 1996, 1997, 1998, 2000, 2001, 2002...
# 2   1990, 1991, 1992, 1994, 1995, 1996, 1997, 1998...
# 3   1990, 1991, 1992, 1994, 1996, 1997, 1998, 1999...
# 4   1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997...
# 5   1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997...
# 6   1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002...
# 7   1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003...
# 8   1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003...
# 9   1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003...
# 10  1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003...
# 11  1998, 1999, 2000, 2001, 2002, 2003, 2004, 2006...
# 12                                   1991, 1992, 1993
# 13           1994, 1995, 1996, 1997, 1998, 1999, 2000
# 14  2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009...
# 15                                   2005, 2006, 2007
# 16  1995, 2003, 2004, 2005, 2006, 2007, 2008, 2009...
# 17  2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009...
# 18  2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009...
# 19  2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011...
# 20  2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011...
# 21  2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015...
# 22  2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015...
# 23                                               2011
# 24                                               2010
# 25                       2017, 2018, 2019, 2020, 2021
# 26                                         2019, 2020
# 27                                         2020, 2021
#
#                                                depths
# 0   0.1, 0.5, 1.0, 3.0, 4.0, 4.5, 5.0, 5.2, 5.5, 5...
# 1                                            0.5, 1.0
# 2              0.0, 0.1, 0.5, 1.0, 2.0, 3.0, 4.0, 8.0
# 3                                  0.0, 0.5, 1.0, 3.0
# 4                             0.0, 0.1, 0.5, 1.0, 2.0
# 5                                  0.0, 0.5, 1.0, 3.0
# 6                                                 0.2
# 7                                                 0.2
# 8                                            0.0, 0.2
# 9                                            0.0, 0.2
# 10                                           0.0, 0.2
# 11                                           0.0, 0.2
# 12                                 0.5, 1.0, 4.0, 5.0
# 13                                      0.0, 0.5, 1.0
# 14                                      0.1, 0.5, 1.0
# 15                                           0.0, 0.3
# 16  0.0, 0.1, 0.15, 0.2, 0.3, 0.4, 0.5, 1.0, 1.8, ...
# 17                                           0.0, 0.2
# 18                                           0.0, 0.2
# 19                                           0.0, 0.2
# 20                                           0.0, 0.2
# 21            0.0, 0.1, 0.15, 0.2, 0.3, 0.5, 1.0, 2.0
# 22  0.0, 0.1, 0.2, 0.24, 0.25, 0.27, 0.3, 0.31, 0....
# 23                                      0.0, 0.4, 0.5
# 24                                                0.2
# 25                     0.0, 0.1, 0.15, 0.18, 0.2, 0.3
# 26                                                0.2
# 27                                                0.2

# %%
# df_mapping_out.to_csv(PROCESSED_DATA_DIR / 'site_summary_20250424.csv', index=False)
